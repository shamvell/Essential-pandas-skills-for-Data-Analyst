# %%
# 🧠 Essential Pandas Skills for Data Analysts

# %% [raw]
# #This notebook covers the **most important Pandas techniques** every data analyst should know.
#
# Topics include:
# - Data loading and inspection
# - Data cleaning
# - Missing values
# - Grouping and aggregation
# - Filtering and sorting
# - Creating new columns
# - Merging and joining
# - Basic visualizations

# %% [raw]
# 📥 Step 1: Load Required Libraries and Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Load sample dataset
df = pd.read_csv("student_scores (1).csv")
df
# Out:
#     Student_ID  Gender  Math_Score  English_Score  Science_Score
# 0            1    Male          97             83             70
# 1            2  Female          52             30             74
# 2            3    Male          78             48             99
# 3            4    Male          68             31             72
# 4            5    Male          96             82             91
# ..         ...     ...         ...            ...            ...
# 95          96  Female          37             35             84
# 96          97  Female          90             66             71
# 97          98  Female          93             53             91
# 98          99  Female          36             75             69
# 99         100    Male          36             82             86
#
# [100 rows x 5 columns]

# %%
🔍 Step 2: Inspect the Dataset

# %%
df.head()
df.tail()
df.info()
df.describe()
df.shape
df.columns

# %%
df.head()
# Out:
#    Student_ID  Gender  Math_Score  English_Score  Science_Score
# 0           1    Male          97             83             70
# 1           2  Female          52             30             74
# 2           3    Male          78             48             99
# 3           4    Male          68             31             72
# 4           5    Male          96             82             91

# %%
df.tail()
# Out:
#     Student_ID  Gender  Math_Score  English_Score  Science_Score
# 95          96  Female          37             35             84
# 96          97  Female          90             66             71
# 97          98  Female          93             53             91
# 98          99  Female          36             75             69
# 99         100    Male          36             82             86

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Student_ID     100 non-null    int64
#  1   Gender         100 non-null    object
#  2   Math_Score     100 non-null    int64
#  3   English_Score  100 non-null    int64
#  4   Science_Score  100 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 4.0+ KB

# %%
df.describe()
# Out:
#        Student_ID  Math_Score  English_Score  Science_Score
# count  100.000000  100.000000     100.000000     100.000000
# mean    50.500000   67.490000      60.490000      71.830000
# std     29.011492   20.344753      17.706071      17.191174
# min      1.000000   35.000000      30.000000      40.000000
# 25%     25.750000   48.750000      48.000000      61.000000
# 50%     50.500000   68.000000      61.000000      72.000000
# 75%     75.250000   85.250000      77.000000      86.000000
# max    100.000000   99.000000      93.000000      99.000000

# %%
df.shape
# Out:
# (100, 5)

# %%
df.columns
# Out:
# Index(['Student_ID', 'Gender', 'Math_Score', 'English_Score', 'Science_Score'], dtype='object')

# %%
🧹 Step 3: Check for Missing Values

# %%
df.isnull().sum()
# Out:
# Student_ID       0
# Gender           0
# Math_Score       0
# English_Score    0
# Science_Score    0
# dtype: int64

# %%
🔎 Step 4: Filter Students with Math Score > 80

# %%
df[df["Math_Score"] > 80]
# Out:
#     Student_ID  Gender  Math_Score  English_Score  Science_Score
# 0            1    Male          97             83             70
# 4            5    Male          96             82             91
# 6            7    Male          82             61             71
# 8            9    Male          96             84             72
# 10          11    Male          87             46             57
# 13          14    Male          94             40             70
# 18          19  Female          99             88             85
# 22          23  Female          97             49             86
# 35          36    Male          82             45             93
# 37          38    Male          96             31             78
# 41          42    Male          99             66             65
# 42          43  Female          81             61             74
# 51          52  Female          85             53             75
# ...

# %%
#Use bitwise AND (&)
df[(df["Math_Score"] > 80) & 
   (df["English_Score"] > 80) & 
   (df["Science_Score"] > 80)]
# Out:
#     Student_ID  Gender  Math_Score  English_Score  Science_Score
# 4            5    Male          96             82             91
# 18          19  Female          99             88             85
# 83          84  Female          85             93             99
# 89          90  Female          96             93             83

# %%
#This means: check if all selected columns are greater than 90 for each row.

df[df[["Math_Score", "English_Score", "Science_Score"]].gt(80).all(axis=1)]
# Out:
#     Student_ID  Gender  Math_Score  English_Score  Science_Score
# 4            5    Male          96             82             91
# 18          19  Female          99             88             85
# 83          84  Female          85             93             99
# 89          90  Female          96             93             83

# %%
#This means: check if any columns are greater than 90 for each row.
df[df[["Math_Score", "English_Score", "Science_Score"]].gt(90).any(axis=1)]
# Out:
#     Student_ID  Gender  Math_Score  English_Score  Science_Score
# 0            1    Male          97             83             70
# 2            3    Male          78             48             99
# 4            5    Male          96             82             91
# 8            9    Male          96             84             72
# 13          14    Male          94             40             70
# 14          15  Female          75             45             93
# 15          16    Male          63             88             97
# 18          19  Female          99             88             85
# 22          23  Female          97             49             86
# 35          36    Male          82             45             93
# 37          38    Male          96             31             78
# 40          41    Male          69             41             94
# 41          42    Male          99             66             65
# ...

# %%
🔢 Step 5: Sort by English Score

# %%
df.sort_values(by="English_Score", ascending=False).head()
# Out:
#     Student_ID  Gender  Math_Score  English_Score  Science_Score
# 89          90  Female          96             93             83
# 83          84  Female          85             93             99
# 84          85    Male          78             90             76
# 58          59    Male          63             90             53
# 36          37  Female          57             89             87

# %%
📊 Step 6: Group by Gender and Get Average Scores

# %%
df.groupby("Gender")[["Math_Score", "English_Score", "Science_Score"]].mean()
# Out:
#         Math_Score  English_Score  Science_Score
# Gender
# Female   65.571429      61.142857      70.392857
# Male     69.931818      59.659091      73.659091

# %%
➕ Step 7: Create New Column - Total Score

# %%
df["Total_Score"] = df["Math_Score"] + df["English_Score"] + df["Science_Score"]
df.head()
# Out:
#    Student_ID  Gender  Math_Score  English_Score  Science_Score  Total_Score
# 0           1    Male          97             83             70          250
# 1           2  Female          52             30             74          156
# 2           3    Male          78             48             99          225
# 3           4    Male          68             31             72          171
# 4           5    Male          96             82             91          269

# %%
✅ Step 8: Create Pass/Fail Column

# %%
df["Result"] = np.where(df["Total_Score"] >= 180, "Pass", "Fail")
df.head()
# Out:
#    Student_ID  Gender  Math_Score  English_Score  Science_Score  Total_Score  \
# 0           1    Male          97             83             70          250
# 1           2  Female          52             30             74          156
# 2           3    Male          78             48             99          225
# 3           4    Male          68             31             72          171
# 4           5    Male          96             82             91          269
#
#   Result
# 0   Pass
# 1   Fail
# 2   Pass
# 3   Fail
# 4   Pass

# %%
📈 Step 9: Bar Chart - Average Scores by Gender

# %%
df.groupby("Gender")[["Math_Score", "English_Score", "Science_Score"]].mean().plot(kind='bar')
plt.title("Average Scores by Gender")
plt.ylabel("Score")
plt.tight_layout()
plt.show()

# %%
🔗 Step 10: Merge with Another DataFrame

# %%
# Create a dummy DataFrame with age data
age_data = pd.DataFrame({
    "Student_ID": range(1, 101),
    "Age": np.random.randint(14, 18, size=100)
})

# Merge
df_merged = pd.merge(df, age_data, on="Student_ID")
df_merged.head()
# Out:
#    Student_ID  Gender  Math_Score  English_Score  Science_Score  Total_Score  \
# 0           1    Male          97             83             70          250
# 1           2  Female          52             30             74          156
# 2           3    Male          78             48             99          225
# 3           4    Male          68             31             72          171
# 4           5    Male          96             82             91          269
#
#   Result  Age
# 0   Pass   16
# 1   Fail   14
# 2   Pass   17
# 3   Fail   14
# 4   Pass   16
